# %% [markdown]
# First we need to import Numpy and CSV so we can parse the spam test data

# %%
import csv
import re
from math import floor

# %% [markdown]
# Now lets open the spam.csv and read the data

# %% [markdown]
# First lets create a list to store the 2 categories of messages
#
# 0 <- ham/not spam
#
# 1 <- spam messages

# %%
messages = [[], []]

# %%
with open('spam.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)

    header = next(reader)
    
    for lines in reader:
        # ham (means regular message)
        if lines[0] == 'ham':
            messages[0].append(lines[1])
            
        elif lines[0] == 'spam':
            messages[1].append(lines[1])

# %% [markdown]
# Now we will take a random 70/30 split from each category for train and test

# %%
# training split params
train = 0.7
total_good = len(messages[0])
total_spam = len(messages[1])

# Split for normal messages
x_train_good = floor(train * total_good)
x_test_good = total_good - x_train_good

# Split for spam messages
x_train_spam = floor(train * total_spam)
x_test_spam = total_spam - x_train_spam

print(x_train_good, x_test_good, x_train_spam, x_test_spam)
# Out:
# 3377 1448 522 225

# %% [markdown]
# Now we will split into a train and test dataset
#
# can also shuffle the list to randomize order if needed but we will just pick the first x amount

# %%
# Mark if a word appears in a spam message
def parse_message_into_vectors(message):
    # first let's lower the message
    lowered_message = message.lower()
    
    # Now lets remove symbols
    # alphabet_numbers = re.sub(r'[^A-Za-z0-9]', '', lowered_message)
    
    # Now Numbers
    alphabet = re.sub(r'[^A-Za-z ]', '', lowered_message)
    
    # Split into a list so we can iterate through
    with_spaces = alphabet.split(" ")
    cleaned = [w for w in with_spaces if w.strip() != '']
    
    
    return with_spaces

# %% [markdown]
# Next we need to go through the train data for good and spam messages and get the totals for each word
#
# first we keep a counter of total words
#
# so first we loop through all

# %%
# Compute a word count for each message and combine them
def create_word_count(messages):
    
    total_msg_counts = len(messages)
    
    returned_dict = {}
    
    for i in messages:
        out = parse_message_into_vectors(i)
        
        # Append the keys to the dictionary
        for d in out:
            if d not in returned_dict:
                returned_dict[d] = 1
            else:
                returned_dict[d] += 1
                
    # compute the probability that a word appears in spam messages
    for i in returned_dict.keys():
        returned_dict[i] = returned_dict[i]/total_msg_counts
                
    return returned_dict

# %%
# Create the train Jsons
x_train_good_word_counts = create_word_count(messages[0][:x_train_good])
x_train_spam_word_counts = create_word_count(messages[1][:x_train_spam])

for i in x_train_good_word_counts.keys():
    if i not in x_train_spam_word_counts:
        x_train_spam_word_counts[i] = 0

for i in x_train_spam_word_counts.keys():
    if i not in x_train_good_word_counts:
        x_train_good_word_counts[i] = 0

#print(x_train_good_word_counts)
# print(x_train_spam_word_counts)

# %% [markdown]
# Now we need to make a method that can use Bayes Theorem to calculate given a sequence of words, good words counts, spam words counts

# %%
# Bayes Theorem given a list of words, the spam word probabilities and good word probabilities
def computeProbabilityOfSpam(listOfWords, spamWords, goodWords):
    top = 1
    bottomLeft = 1
    bottomRight = 1
    
    for i in listOfWords:
        if i in spamWords and i in goodWords:
            top*= spamWords[i]
            bottomLeft *= spamWords[i]
            bottomRight *= goodWords[i]
            
    if (bottomLeft + bottomRight) == 0:
        return 0
    
    return top/(bottomLeft+bottomRight)

# %%
# Now we need to compute the probabilities for messages that count as spam
probability_scores = []

for i in messages[1][:x_train_spam]:
    formatted_msg = parse_message_into_vectors(i)
    
    print("Message: ", formatted_msg)
    
    
    prob = computeProbabilityOfSpam(formatted_msg, x_train_spam_word_counts, x_train_good_word_counts)
    print("Probability of Spam: ", prob)
    
    probability_scores.append(prob)

avg = 0
for i in probability_scores:
    avg += i
avg /= len(probability_scores)

print("Average Probability of Spam: ", avg)
# Out:
# Message:  ['free', 'entry', 'in', '', 'a', 'wkly', 'comp', 'to', 'win', 'fa', 'cup', 'final', 'tkts', 'st', 'may', '', 'text', 'fa', 'to', '', 'to', 'receive', 'entry', 'questionstd', 'txt', 'ratetcs', 'apply', 'overs']
# Probability of Spam:  1.0
# Message:  ['freemsg', 'hey', 'there', 'darling', 'its', 'been', '', 'weeks', 'now', 'and', 'no', 'word', 'back', 'id', 'like', 'some', 'fun', 'you', 'up', 'for', 'it', 'still', 'tb', 'ok', 'xxx', 'std', 'chgs', 'to', 'send', '', 'to', 'rcv']
# Probability of Spam:  1.0
# Message:  ['winner', 'as', 'a', 'valued', 'network', 'customer', 'you', 'have', 'been', 'selected', 'to', 'receivea', '', 'prize', 'reward', 'to', 'claim', 'call', '', 'claim', 'code', 'kl', 'valid', '', 'hours', 'only']
# Probability of Spam:  1.0
# Message:  ['had', 'your', 'mobile', '', 'months', 'or', 'more', 'u', 'r', 'entitled', 'to', 'update', 'to', 'the', 'latest', 'colour', 'mobiles', 'with', 'camera', 'for', 'free', 'call', 'the', 'mobile', 'update', 'co', 'free', 'on', '']
# Probability of Spam:  1.0
# Message:  ['six', 'chances', 'to', 'win', 'cash', 'from', '', 'to', '', 'pounds', 'txt', 'csh', 'and', 'send', 'to', '', 'cost', 'pday', 'days', '', 'tsandcs', 'apply', 'reply', 'hl', '', 'info']
# Probability of Spam:  1.0
# Message:  ['urgent', 'you', 'have', 'won', 'a', '', 'week', 'free', 'membership', 'in', 'our', '', 'prize', 'jackpot', 'txt', 'the', 'word', 'claim', 'to', 'no', '', 'tc', 'wwwdbuknet', 'lccltd', 'pobox', 'ldnwarw']
# Probability of Spam:  1.0
# Message:  ['xxxmobilemovieclub', 'to', 'use', 'your', 'credit', 'click', 'the', 'wap', 'link', 'in', 'the', 'next', 'txt', 'message', 'or', 'click', 'here', 'httpwap', 'xxxmobilemovieclubcomnqjkgighjjgcbl']
# Probability of Spam:  1.0
# Message:  ['england', 'v', 'macedonia', '', 'dont', 'miss', 'the', 'goalsteam', 'news', 'txt', 'ur', 'national', 'team', 'to', '', 'eg', 'england', 'to', '', 'trywales', 'scotland', 'txt', 'poboxoxwwq', '']
# Probability of Spam:  1.0
# Message:  ['thanks', 'for', 'your', 'subscription', 'to', 'ringtone', 'uk', 'your', 'mobile', 'will', 'be', 'charged', 'month', 'please', 'confirm', 'by', 'replying', 'yes', 'or', 'no', 'if', 'you', 'reply', 'no', 'you', 'will', 'not', 'be', 'charged']
# Probability of Spam:  1.0
# Message:  ['', '', 'rodger', 'burns', '', 'msg', '', 'we', 'tried', 'to', 'call', 'you', 're', 'your', 'reply', 'to', 'our', 'sms', 'for', 'a', 'free', 'nokia', 'mobile', '', 'free', 'camcorder', 'please', 'call', 'now', '', 'for', 'delivery', 'tomorrow']
# Probability of Spam:  1.0
# Message:  ['sms', 'ac', 'sptv', 'the', 'new', 'jersey', 'devils', 'and', 'the', 'detroit', 'red', 'wings', 'play', 'ice', 'hockey', 'correct', 'or', 'incorrect', 'end', 'reply', 'end', 'sptv']
# Probability of Spam:  1.0
# Message:  ['congrats', '', 'year', 'special', 'cinema', 'pass', 'for', '', 'is', 'yours', 'call', '', 'now', 'c', 'suprman', 'v', 'matrix', 'starwars', 'etc', 'all', '', 'free', 'bxipwe', 'pm', 'dont', 'miss', 'out']
# Probability of Spam:  1.0
# Message:  ['as', 'a', 'valued', 'customer', 'i', 'am', 'pleased', 'to', 'advise', 'you', 'that', 'following', 'recent', 'review', 'of', 'your', 'mob', 'no', 'you', 'are', 'awarded', 'with', 'a', '', 'bonus', 'prize', 'call', '']
# Probability of Spam:  1.0
# Message:  ['urgent', 'ur', 'awarded', 'a', 'complimentary', 'trip', 'to', 'eurodisinc', 'trav', 'acoentry', 'or', '', 'to', 'claim', 'txt', 'dis', 'to', '', 'morefrmmob', 'shracomorsglsuplt', 'ls', 'aj']
# Probability of Spam:  1.0
# Message:  ['did', 'you', 'hear', 'about', 'the', 'new', 'divorce', 'barbie', 'it', 'comes', 'with', 'all', 'of', 'kens', 'stuff']
# Probability of Spam:  1.0
# Message:  ['please', 'call', 'our', 'customer', 'service', 'representative', 'on', '', '', '', 'between', 'ampm', 'as', 'you', 'have', 'won', 'a', 'guaranteed', '', 'cash', 'or', '', 'prize']
# Probability of Spam:  1.0
# Message:  ['your', 'free', 'ringtone', 'is', 'waiting', 'to', 'be', 'collected', 'simply', 'text', 'the', 'password', 'mix', 'to', '', 'to', 'verify', 'get', 'usher', 'and', 'britney', 'fml', 'po', 'box', '', 'mk', 'h', 'ppw', '']
# Probability of Spam:  1.0
# Message:  ['gent', 'we', 'are', 'trying', 'to', 'contact', 'you', 'last', 'weekends', 'draw', 'shows', 'that', 'you', 'won', 'a', '', 'prize', 'guaranteed', 'call', '', 'claim', 'code', 'k', 'valid', 'hrs', 'only', 'ppm']
# Probability of Spam:  1.0
# Message:  ['you', 'are', 'a', 'winner', 'u', 'have', 'been', 'specially', 'selected', '', 'receive', '', 'or', 'a', '', 'holiday', 'flights', 'inc', 'speak', 'to', 'a', 'live', 'operator', '', 'claim', 'pmin', '']
# Probability of Spam:  1.0
# Message:  ['private', 'your', '', 'account', 'statement', 'for', '', 'shows', '', 'unredeemed', 'bonus', 'points', 'to', 'claim', 'call', '', 'identifier', 'code', '', 'expires']
# Probability of Spam:  1.0
# Message:  ['urgent', 'your', 'mobile', 'no', 'was', 'awarded', '', 'bonus', 'caller', 'prize', 'on', '', 'this', 'is', 'our', 'final', 'try', 'to', 'contact', 'u', 'call', 'from', 'landline', '', 'boxwrc', 'ppm']
# Probability of Spam:  1.0
# Message:  ['todays', 'voda', 'numbers', 'ending', '', 'are', 'selected', 'to', 'receive', 'a', '', 'award', 'if', 'you', 'have', 'a', 'match', 'please', 'call', '', 'quoting', 'claim', 'code', '', 'standard', 'rates', 'app']
# Probability of Spam:  1.0
# Message:  ['sunshine', 'quiz', 'wkly', 'q', 'win', 'a', 'top', 'sony', 'dvd', 'player', 'if', 'u', 'know', 'which', 'country', 'the', 'algarve', 'is', 'in', 'txt', 'ansr', 'to', '', '', 'sptyrone']
# Probability of Spam:  1.0
# Message:  ['want', '', 'get', 'laid', 'tonight', 'want', 'real', 'dogging', 'locations', 'sent', 'direct', '', 'ur', 'mob', 'join', 'the', 'uks', 'largest', 'dogging', 'network', 'bt', 'txting', 'gravel', 'to', '', 'nt', 'eca', 'pmsgp']
# Probability of Spam:  1.0
# Message:  ['youll', 'not', 'rcv', 'any', 'more', 'msgs', 'from', 'the', 'chat', 'svc', 'for', 'free', 'hardcore', 'services', 'text', 'go', 'to', '', 'if', 'u', 'get', 'nothing', 'u', 'must', 'age', 'verify', 'with', 'yr', 'network', '', 'try', 'again']
# Probability of Spam:  1.0
# Message:  ['freemsg', 'why', 'havent', 'you', 'replied', 'to', 'my', 'text', 'im', 'randy', 'sexy', 'female', 'and', 'live', 'local', 'luv', 'to', 'hear', 'from', 'u', 'netcollex', 'ltd', 'p', 'per', 'msg', 'reply', 'stop', 'to', 'end']
# Probability of Spam:  1.0
# Message:  ['customer', 'service', 'annoncement', 'you', 'have', 'a', 'new', 'years', 'delivery', 'waiting', 'for', 'you', 'please', 'call', '', 'now', 'to', 'arrange', 'delivery']
# Probability of Spam:  1.0
# Message:  ['you', 'are', 'a', 'winner', 'u', 'have', 'been', 'specially', 'selected', '', 'receive', '', 'cash', 'or', 'a', '', 'holiday', 'flights', 'inc', 'speak', 'to', 'a', 'live', 'operator', '', 'claim', '']
# Probability of Spam:  1.0
# Message:  ['pls', 'stop', 'bootydelious', 'f', 'is', 'inviting', 'you', 'to', 'be', 'her', 'friend', 'reply', 'yes', 'or', 'no', 'see', 'her', 'wwwsmsacubootydelious', 'stop', 'send', 'stop', 'frnd', 'to', '']
# Probability of Spam:  1.0
# Message:  ['bangbabes', 'ur', 'order', 'is', 'on', 'the', 'way', 'u', 'should', 'receive', 'a', 'service', 'msg', '', 'download', 'ur', 'content', 'if', 'u', 'do', 'not', 'goto', 'wap', 'bangb', 'tv', 'on', 'ur', 'mobile', 'internetservice', 'menu']
# Probability of Spam:  1.0
# Message:  ['urgent', 'we', 'are', 'trying', 'to', 'contact', 'you', 'last', 'weekends', 'draw', 'shows', 'that', 'you', 'have', 'won', 'a', '', 'prize', 'guaranteed', 'call', '', 'claim', 'code', 's', 'valid', 'hrs', 'only']
# Probability of Spam:  1.0
# Message:  ['please', 'call', 'our', 'customer', 'service', 'representative', 'on', 'freephone', '', '', '', 'between', 'ampm', 'as', 'you', 'have', 'won', 'a', 'guaranteed', '', 'cash', 'or', '', 'prize']
# Probability of Spam:  1.0
# Message:  ['are', 'you', 'unique', 'enough', 'find', 'out', 'from', 'th', 'august', 'wwwareyouuniquecouk']
# Probability of Spam:  1.0
# Message:  ['', 'new', 'mobiles', 'from', '', 'must', 'go', 'txt', 'nokia', 'to', 'no', '', '', 'collect', 'yours', 'todayfrom', 'only', '', 'wwwtcbiz', 'optout', 'gbpmtmsg']
# Probability of Spam:  1.0
# Message:  ['will', 'u', 'meet', 'ur', 'dream', 'partner', 'soon', 'is', 'ur', 'career', 'off', '', 'a', 'flyng', 'start', '', 'find', 'out', 'free', 'txt', 'horo', 'followed', 'by', 'ur', 'star', 'sign', 'e', 'g', 'horo', 'aries']
# Probability of Spam:  1.0
# Message:  ['text', '', 'meet', 'someone', 'sexy', 'today', 'u', 'can', 'find', 'a', 'date', 'or', 'even', 'flirt', 'its', 'up', 'to', 'u', 'join', '', 'just', 'p', 'reply', 'with', 'name', '', 'age', 'eg', 'sam', '', '', 'msg', 'recdthirtyeight', 'pence']
# Probability of Spam:  1.0
# Message:  ['u', '', 'have', 'a', 'secret', 'admirer', 'who', 'is', 'looking', '', 'make', 'contact', 'with', 'ufind', 'out', 'who', 'they', 'rreveal', 'who', 'thinks', 'ur', 'so', 'specialcall', 'on', '']
# Probability of Spam:  1.0
# Message:  ['congratulations', 'ur', 'awarded', '', 'of', 'cd', 'vouchers', 'or', 'gift', 'guaranteed', '', 'free', 'entry', '', '', 'wkly', 'draw', 'txt', 'music', 'to', '', 'tncs', 'wwwldewcomwinppmxage']
# Probability of Spam:  1.0
# Message:  ['we', 'tried', 'to', 'contact', 'you', 're', 'your', 'reply', 'to', 'our', 'offer', 'of', 'a', 'video', 'handset', '', 'anytime', 'networks', 'mins', 'unlimited', 'text', 'camcorder', 'reply', 'or', 'call', '', 'now']
# Probability of Spam:  1.0
# Message:  ['hey', 'i', 'am', 'really', 'horny', 'want', 'to', 'chat', 'or', 'see', 'me', 'naked', 'text', 'hot', 'to', '', 'text', 'charged', 'at', 'pm', 'to', 'unsubscribe', 'text', 'stop', '']
# Probability of Spam:  1.0
# Message:  ['ur', 'ringtone', 'service', 'has', 'changed', '', 'free', 'credits', 'go', 'to', 'clubmobilescom', 'to', 'choose', 'content', 'now', 'stop', 'txt', 'club', 'stop', 'to', '', 'pwk', 'club', 'po', 'box', 'mk', 'wt']
# Probability of Spam:  1.0
# Message:  ['ringtone', 'club', 'get', 'the', 'uk', 'singles', 'chart', 'on', 'your', 'mobile', 'each', 'week', 'and', 'choose', 'any', 'top', 'quality', 'ringtone', 'this', 'message', 'is', 'free', 'of', 'charge']
# Probability of Spam:  1.0
# Message:  ['hmv', 'bonus', 'special', '', 'pounds', 'of', 'genuine', 'hmv', 'vouchers', 'to', 'be', 'won', 'just', 'answer', '', 'easy', 'questions', 'play', 'now', 'send', 'hmv', 'to', '', 'more', 'infowwwpercentrealcom']
# Probability of Spam:  1.0
# Message:  ['tmobile', 'customer', 'you', 'may', 'now', 'claim', 'your', 'free', 'camera', 'phone', 'upgrade', '', 'a', 'pay', '', 'go', 'sim', 'card', 'for', 'your', 'loyalty', 'call', 'on', '', '', 'offer', 'ends', 'thfebtcs', 'apply']
# Probability of Spam:  1.0
# Message:  ['sms', 'ac', 'blind', 'date', 'u', 'rodds', 'is', 'm', 'from', 'aberdeen', 'united', 'kingdom', 'check', 'him', 'out', 'httpimg', 'sms', 'acwicmbcktzr', 'no', 'blind', 'dates', 'send', 'hide']
# Probability of Spam:  1.0
# Message:  ['themob', 'check', 'out', 'our', 'newest', 'selection', 'of', 'content', 'games', 'tones', 'gossip', 'babes', 'and', 'sport', 'keep', 'your', 'mobile', 'fit', 'and', 'funky', 'text', 'wap', 'to', '']
# Probability of Spam:  1.0
# Message:  ['think', 'ur', 'smart', '', 'win', '', 'this', 'week', 'in', 'our', 'weekly', 'quiz', 'text', 'play', 'to', '', 'nowtcs', 'winnersclub', 'po', 'box', '', 'm', 'uz', '', 'gbpweek']
# Probability of Spam:  1.0
# Message:  ['december', 'only', 'had', 'your', 'mobile', 'mths', 'you', 'are', 'entitled', 'to', 'update', 'to', 'the', 'latest', 'colour', 'camera', 'mobile', 'for', 'free', 'call', 'the', 'mobile', 'update', 'co', 'free', 'on', '']
# Probability of Spam:  1.0
# Message:  ['call', 'germany', 'for', 'only', '', 'pence', 'per', 'minute', 'call', 'from', 'a', 'fixed', 'line', 'via', 'access', 'number', '', '', '', '', 'no', 'prepayment', 'direct', 'access']
# Probability of Spam:  1.0
# Message:  ['valentines', 'day', 'special', 'win', 'over', '', 'in', 'our', 'quiz', 'and', 'take', 'your', 'partner', 'on', 'the', 'trip', 'of', 'a', 'lifetime', 'send', 'go', 'to', '', 'now', 'pmsg', 'rcvd', 'custcare']
# Probability of Spam:  1.0
# Message:  ['fancy', 'a', 'shag', 'i', 'dointerested', 'sextextukcom', 'txt', 'xxuk', 'suzy', 'to', '', 'txts', 'cost', '', 'per', 'msg', 'tncs', 'on', 'website', 'x']
# Probability of Spam:  1.0
# Message:  ['congratulations', 'ur', 'awarded', '', 'of', 'cd', 'vouchers', 'or', 'gift', 'guaranteed', '', 'free', 'entry', '', '', 'wkly', 'draw', 'txt', 'music', 'to', '', 'tncs', 'wwwldewcomwinppmxage']
# Probability of Spam:  1.0
# Message:  ['ur', 'cashbalance', 'is', 'currently', '', 'pounds', '', 'to', 'maximize', 'ur', 'cashin', 'now', 'send', 'cash', 'to', '', 'only', 'pmsg', 'cc', '', 'hgsuitelands', 'rowwjhl']
# Probability of Spam:  1.0
# Message:  ['updatenow', '', 'xmas', 'offer', 'latest', 'motorola', 'sonyericsson', '', 'nokia', '', 'free', 'bluetooth', 'double', 'mins', '', '', 'txt', 'on', 'orange', 'call', 'mobileupd', 'on', '', 'or', 'calloptoutfq']
# Probability of Spam:  1.0
# Message:  ['here', 'is', 'your', 'discount', 'code', 'rp', 'to', 'stop', 'further', 'messages', 'reply', 'stop', 'wwwregalportfoliocouk', 'customer', 'services', '']
# Probability of Spam:  1.0
# Message:  ['thanks', 'for', 'your', 'ringtone', 'order', 'reference', 't', 'you', 'will', 'be', 'charged', 'gbp', '', 'per', 'week', 'you', 'can', 'unsubscribe', 'at', 'anytime', 'by', 'calling', 'customer', 'services', 'on', '']
# Probability of Spam:  1.0
# Message:  ['double', 'mins', 'and', 'txts', '', 'months', 'free', 'bluetooth', 'on', 'orange', 'available', 'on', 'sony', 'nokia', 'motorola', 'phones', 'call', 'mobileupd', 'on', '', 'or', 'calloptoutndx']
# Probability of Spam:  1.0
# Message:  ['mths', 'half', 'price', 'orange', 'line', 'rental', '', 'latest', 'camera', 'phones', '', 'free', 'had', 'your', 'phone', 'mths', '', 'call', 'mobilesdirect', 'free', 'on', '', 'to', 'update', 'now', 'orstoptxt']
# Probability of Spam:  1.0
# Message:  ['free', 'ringtone', 'text', 'first', 'to', '', 'for', 'a', 'poly', 'or', 'text', 'get', 'to', '', 'for', 'a', 'true', 'tone', 'help', '', '', '', 'after', 'st', 'free', 'tones', 'are', 'xpw', 'to', 'end', 'txt', 'stop']
# Probability of Spam:  1.0
# Message:  ['', 'dating', 'service', 'call', '', 'boxskch']
# Probability of Spam:  1.0
# Message:  ['free', 'entry', 'into', 'our', '', 'weekly', 'competition', 'just', 'text', 'the', 'word', 'win', 'to', '', 'now', '', 'tc', 'wwwtxttowincouk']
# Probability of Spam:  1.0
# Message:  ['send', 'a', 'logo', '', 'ur', 'lover', '', '', 'names', 'joined', 'by', 'a', 'heart', 'txt', 'love', 'name', 'name', 'mobno', 'eg', 'love', 'adam', 'eve', '', 'to', '', 'yahoo', 'poboxwwq', 'txtno', '', 'no', 'ads', 'p']
# Probability of Spam:  1.0
# Message:  ['someone', 'has', 'contacted', 'our', 'dating', 'service', 'and', 'entered', 'your', 'phone', 'because', 'they', 'fancy', 'you', 'to', 'find', 'out', 'who', 'it', 'is', 'call', 'from', 'a', 'landline', '', '', 'poboxntfp']
# Probability of Spam:  1.0
# Message:  ['urgent', 'your', 'mobile', 'number', 'has', 'been', 'awarded', 'with', 'a', '', 'prize', 'guaranteed', 'call', '', 'from', 'land', 'line', 'claim', '', 'valid', 'hrs', 'only']
# Probability of Spam:  1.0
# Message:  ['congrats', 'nokia', '', 'video', 'camera', 'phone', 'is', 'your', 'call', '', 'calls', 'cost', 'ppm', 'ave', 'call', 'mins', 'vary', 'from', 'mobiles', '', 'close', '', 'post', 'bcm', 'ldn', 'wcnxx']
# Probability of Spam:  1.0
# Message:  ['loan', 'for', 'any', 'purpose', '', '', '', 'homeowners', '', 'tenants', 'welcome', 'have', 'you', 'been', 'previously', 'refused', 'we', 'can', 'still', 'help', 'call', 'free', '', '', 'or', 'text', 'back', 'help']
# Probability of Spam:  1.0
# Message:  ['upgrdcentre', 'orange', 'customer', 'you', 'may', 'now', 'claim', 'your', 'free', 'camera', 'phone', 'upgrade', 'for', 'your', 'loyalty', 'call', 'now', 'on', '', '', '', 'offer', 'ends', 'th', 'july', 'tcs', 'apply', 'optout', 'available']
# Probability of Spam:  1.0
# Message:  ['okmail', 'dear', 'dave', 'this', 'is', 'your', 'final', 'notice', 'to', 'collect', 'your', '', 'tenerife', 'holiday', 'or', '', 'cash', 'award', 'call', '', 'from', 'landline', 'tcs', 'sae', 'box', 'cwwx', 'ppm']
# Probability of Spam:  1.0
# Message:  ['want', '', 'get', 'laid', 'tonight', 'want', 'real', 'dogging', 'locations', 'sent', 'direct', '', 'ur', 'mob', 'join', 'the', 'uks', 'largest', 'dogging', 'network', 'by', 'txting', 'moan', 'to', 'nyt', 'eca', 'pmsgp']
# Probability of Spam:  1.0
# Message:  ['free', 'message', 'activate', 'your', '', 'free', 'text', 'messages', 'by', 'replying', 'to', 'this', 'message', 'with', 'the', 'word', 'free', 'for', 'terms', '', 'conditions', 'visit', 'wwwcom']
# Probability of Spam:  1.0
# Message:  ['congrats', '', 'year', 'special', 'cinema', 'pass', 'for', '', 'is', 'yours', 'call', '', 'now', 'c', 'suprman', 'v', 'matrix', 'starwars', 'etc', 'all', '', 'free', 'bxipwe', 'pm', 'dont', 'miss', 'out']
# Probability of Spam:  1.0
# Message:  ['error']
# Probability of Spam:  1.0
# Message:  ['you', 'are', 'guaranteed', 'the', 'latest', 'nokia', 'phone', 'a', 'gb', 'ipod', 'mp', 'player', 'or', 'a', '', 'prize', 'txt', 'word', 'collect', 'to', 'no', '', 'ibhltd', 'ldnwh', 'pmtmsgrcvd']
# Probability of Spam:  1.0
# Message:  ['boltblue', 'tones', 'for', 'p', 'reply', 'poly', 'or', 'mono', 'eg', 'poly', '', 'cha', 'cha', 'slide', '', 'yeah', '', 'slow', 'jamz', '', 'toxic', '', 'come', 'with', 'me', 'or', 'stop', '', 'more', 'tones', 'txt', 'more']
# Probability of Spam:  1.0
# Message:  ['your', 'credits', 'have', 'been', 'topped', 'up', 'for', 'httpwwwbubbletextcom', 'your', 'renewal', 'pin', 'is', 'tgxxrz']
# Probability of Spam:  1.0
# Message:  ['urgent', 'your', 'mobile', 'no', 'was', 'awarded', 'a', '', 'bonus', 'caller', 'prize', 'on', '', 'this', 'is', 'our', 'nd', 'attempt', 'to', 'contact', 'you', 'call', '', 'boxqu']
# Probability of Spam:  1.0
# Message:  ['todays', 'offer', 'claim', 'ur', '', 'worth', 'of', 'discount', 'vouchers', 'text', 'yes', 'to', '', 'now', 'savamob', 'member', 'offers', 'mobile', 't', 'cs', '', '', 'sub', '', '', 'unsub', 'reply', 'x']
# Probability of Spam:  1.0
# Message:  ['you', 'will', 'recieve', 'your', 'tone', 'within', 'the', 'next', 'hrs', 'for', 'terms', 'and', 'conditions', 'please', 'see', 'channel', 'u', 'teletext', 'pg', '']
# Probability of Spam:  1.0
# Message:  ['private', 'your', '', 'account', 'statement', 'for', '', 'shows', '', 'unredeemed', 'sim', 'points', 'call', '', 'identifier', 'code', '', 'expires', '']
# Probability of Spam:  1.0
# Message:  ['from', 'wwwapplausestorecom', 'monthlysubscriptionpmsg', 'maxmonth', 'tcsc', 'web', 'age', 'stop', 'txt', 'stop']
# Probability of Spam:  1.0
# Message:  ['gent', 'we', 'are', 'trying', 'to', 'contact', 'you', 'last', 'weekends', 'draw', 'shows', 'that', 'you', 'won', 'a', '', 'prize', 'guaranteed', 'call', '', 'claim', 'code', 'k', 'valid', 'hrs', 'only', 'ppm']
# Probability of Spam:  1.0
# Message:  ['you', 'have', 'won', '', 'cash', 'or', 'a', '', 'prize', 'to', 'claim', 'call']
# Probability of Spam:  1.0
# Message:  ['our', 'mobile', 'number', 'has', 'won', '', 'to', 'claim', 'calls', 'us', 'back', 'or', 'ring', 'the', 'claims', 'hot', 'line', 'on', '']
# Probability of Spam:  1.0
# Message:  ['we', 'tried', 'to', 'contact', 'you', 're', 'your', 'reply', 'to', 'our', 'offer', 'of', '', 'mins', '', 'textand', 'a', 'new', 'video', 'phone', 'call', '', 'now', 'or', 'reply', 'for', 'free', 'delivery', 'tomorrow']
# Probability of Spam:  1.0
# Message:  ['for', 'ur', 'chance', 'to', 'win', 'a', '', 'wkly', 'shopping', 'spree', 'txt', 'shop', 'to', '', 'tscs', 'wwwtxtshopcom', 'custcare', '', 'xpwk']
# Probability of Spam:  1.0
# Message:  ['you', 'have', 'been', 'specially', 'selected', 'to', 'receive', 'a', '', 'pound', 'award', 'call', '', 'before', 'the', 'lines', 'close', 'cost', 'ppm', '', 'tcs', 'apply', 'ag', 'promo']
# Probability of Spam:  1.0
# Message:  ['private', 'your', '', 'account', 'statement', 'for', '', 'shows', '', 'unredeemed', 's', 'i', 'm', 'points', 'call', '', 'identifier', 'code', '', 'expires', '']
# Probability of Spam:  1.0
# Message:  ['you', 'have', 'an', 'important', 'customer', 'service', 'announcement', 'call', 'freephone', '', '', '', 'now']
# Probability of Spam:  1.0
# Message:  ['xclusiveclubsaisai', 'morow', '', 'soiree', 'speciale', 'zouk', 'with', 'nichols', 'from', 'parisfree', 'roses', '', 'all', 'ladies', '', 'info', '']
# Probability of Spam:  1.0
# Message:  ['', 'days', 'to', 'kick', 'off', 'for', 'euro', 'u', 'will', 'be', 'kept', 'up', 'to', 'date', 'with', 'the', 'latest', 'news', 'and', 'results', 'daily', 'to', 'be', 'removed', 'send', 'get', 'txt', 'stop', 'to', '']
# Probability of Spam:  1.0
# Message:  ['new', 'textbuddy', 'chat', '', 'horny', 'guys', 'in', 'ur', 'area', '', 'just', 'p', 'free', '', 'receive', 'search', 'postcode', 'or', 'at', 'gaytextbuddycom', 'txt', 'one', 'name', 'to', '']
# Probability of Spam:  1.0
# Message:  ['todays', 'vodafone', 'numbers', 'ending', 'with', '', 'are', 'selected', 'to', 'a', 'receive', 'a', '', 'award', 'if', 'your', 'number', 'matches', 'call', '', 'to', 'receive', 'your', '', 'award']
# Probability of Spam:  1.0
# Message:  ['dear', 'voucher', 'holder', '', 'claim', 'this', 'weeks', 'offer', 'at', 'your', 'pc', 'go', 'to', 'httpwwwetlpcoukexpressoffer', 'tscs', 'apply', 'stop', 'texts', 'txt', 'stop', 'to', '']
# Probability of Spam:  1.0
# Message:  ['private', 'your', '', 'account', 'statement', 'for', 'shows', '', 'unredeemed', 's', 'i', 'm', 'points', 'call', '', 'identifier', 'code', '', 'expires', '']
# Probability of Spam:  1.0
# Message:  ['you', 'have', 'won', '', 'cash', 'or', 'a', '', 'prize', 'to', 'claim', 'call', 'tc', 'rstm', 'sw', 'ss', 'ppm']
# Probability of Spam:  1.0
# Message:  ['', 'and', '', 'are', 'premium', 'phone', 'services', 'call', '']
# Probability of Spam:  1.0
# Message:  ['sms', 'ac', 'sun', 'posts', 'helloyou', 'seem', 'cool', 'wanted', 'to', 'say', 'hi', 'hi', 'stop', 'send', 'stop', 'to', '']
# Probability of Spam:  1.0
# Message:  ['get', 'ur', 'st', 'ringtone', 'free', 'now', 'reply', 'to', 'this', 'msg', 'with', 'tone', 'gr', 'top', '', 'tones', 'to', 'your', 'phone', 'every', 'week', 'just', '', 'per', 'wk', '', 'opt', 'out', 'send', 'stop', '', '']
# Probability of Spam:  1.0
# Message:  ['hi', 'im', 'sue', 'i', 'am', '', 'years', 'old', 'and', 'work', 'as', 'a', 'lapdancer', 'i', 'love', 'sex', 'text', 'me', 'live', '', 'im', 'i', 'my', 'bedroom', 'now', 'text', 'sue', 'to', '', 'by', 'textoperator', 'g', 'da', 'ppmsg', '']
# Probability of Spam:  1.0
# Message:  ['forwarded', 'from', 'please', 'call', '', 'immediately', 'as', 'there', 'is', 'an', 'urgent', 'message', 'waiting', 'for', 'you']
# Probability of Spam:  0.9999999939670966
# Message:  ['to', 'review', 'and', 'keep', 'the', 'fantastic', 'nokia', 'ngage', 'game', 'deck', 'with', 'club', 'nokia', 'go', '', 'wwwcnupdatescomnewsletter', 'unsubscribe', 'from', 'alerts', 'reply', 'with', 'the', 'word', 'out']
# Probability of Spam:  1.0
# Message:  ['mths', 'half', 'price', 'orange', 'line', 'rental', '', 'latest', 'camera', 'phones', '', 'free', 'had', 'your', 'phone', 'mths', 'call', 'mobilesdirect', 'free', 'on', '', 'to', 'update', 'now', 'orstoptxt', 'tcs']
# Probability of Spam:  1.0
# Message:  ['', 'between', 'ampm', 'cost', 'p']
# Probability of Spam:  1.0
# Message:  ['error']
# Probability of Spam:  1.0
# Message:  ['you', 'have', 'won', 'a', 'guaranteed', '', 'cash', 'or', 'a', '', 'prize', 'to', 'claim', 'yr', 'prize', 'call', 'our', 'customer', 'service', 'representative', 'on', '', 'between', 'ampm']
# Probability of Spam:  1.0
# Message:  ['email', 'alertfrom', 'jeri', 'stewartsize', 'kbsubject', 'lowcost', 'prescripiton', 'drvgsto', 'listen', 'to', 'email', 'call', '']
# Probability of Spam:  1.0
# Message:  ['hi', 'customer', 'loyalty', 'offerthe', 'new', 'nokia', 'mobile', 'from', 'only', '', 'at', 'txtauction', 'txt', 'word', 'start', 'to', 'no', '', '', 'get', 'yours', 'now', 'tctxt', 'tc', 'pmtmsg']
# Probability of Spam:  1.0
# Message:  ['u', 'are', 'subscribed', 'to', 'the', 'best', 'mobile', 'content', 'service', 'in', 'the', 'uk', 'for', '', 'per', '', 'days', 'until', 'you', 'send', 'stop', 'to', '', 'helpline', '']
# Probability of Spam:  1.0
# Message:  ['do', 'you', 'realize', 'that', 'in', 'about', '', 'years', 'well', 'have', 'thousands', 'of', 'old', 'ladies', 'running', 'around', 'with', 'tattoos']
# Probability of Spam:  1.0
# Message:  ['you', 'have', 'an', 'important', 'customer', 'service', 'announcement', 'from', 'premier']
# Probability of Spam:  1.0
# Message:  ['romantic', 'paris', '', 'nights', '', 'flights', 'from', '', 'book', 'now', '', 'next', 'year', 'call', 'tscs', 'apply']
# Probability of Spam:  1.0
# Message:  ['urgent', 'ur', '', 'guaranteed', 'award', 'is', 'still', 'unclaimed', 'call', '', 'now', 'closingdate', 'claimcode', 'mm', 'pmmorefrommobilebremovedmobypoboxlsyf']
# Probability of Spam:  1.0
# Message:  ['ur', 'awarded', 'a', 'city', 'break', 'and', 'could', 'win', 'a', '', 'summer', 'shopping', 'spree', 'every', 'wk', 'txt', 'store', 'to', '', '', 'skilgme', 'tscswinawkage', 'perwksub']
# Probability of Spam:  1.0
# Message:  ['you', 'have', 'an', 'important', 'customer', 'service', 'announcement', 'from', 'premier', 'call', 'freephone', '', '', '', 'now']
# Probability of Spam:  1.0
# Message:  ['ever', 'thought', 'about', 'living', 'a', 'good', 'life', 'with', 'a', 'perfect', 'partner', 'just', 'txt', 'back', 'name', 'and', 'age', 'to', 'join', 'the', 'mobile', 'community', 'psms']
# Probability of Spam:  1.0
# Message:  ['', 'free', 'top', 'polyphonic', 'tones', 'call', '', 'national', 'rate', 'get', 'a', 'toppoly', 'tune', 'sent', 'every', 'week', 'just', 'text', 'subpoly', 'to', '', '', 'per', 'pole', 'unsub', '']
# Probability of Spam:  1.0
# Message:  ['orange', 'customer', 'you', 'may', 'now', 'claim', 'your', 'free', 'camera', 'phone', 'upgrade', 'for', 'your', 'loyalty', 'call', 'now', 'on', '', '', '', 'offer', 'ends', 'thmarch', 'tcs', 'apply', 'optout', 'availa']
# Probability of Spam:  1.0
# Message:  ['last', 'chance', 'claim', 'ur', '', 'worth', 'of', 'discount', 'vouchers', 'today', 'text', 'shop', 'to', '', 'now', 'savamob', 'offers', 'mobile', 't', 'cs', 'savamob', 'pobox', 'muz', '', 'sub', '']
# Probability of Spam:  1.0
# Message:  ['free', 'for', 'st', 'week', 'no', 'nokia', 'tone', '', 'ur', 'mobile', 'every', 'week', 'just', 'txt', 'nokia', 'to', '', 'get', 'txting', 'and', 'tell', 'ur', 'mates', 'wwwgetzedcouk', 'pobox', '', 'wwq', '', 'normptone']
# Probability of Spam:  1.0
# Message:  ['you', 'have', 'won', 'a', 'guaranteed', '', 'award', 'or', 'even', '', 'cashto', 'claim', 'ur', 'award', 'call', 'free', 'on', '', '', '', 'stop', 'getstop', 'on', '', 'php', 'rg', 'jx']
# Probability of Spam:  1.0
# Message:  ['congratulations', 'ur', 'awarded', 'either', '', 'of', 'cd', 'gift', 'vouchers', '', 'free', 'entry', '', 'our', '', 'weekly', 'draw', 'txt', 'music', 'to', '', 'tncs', 'wwwldewcomwinppmxage']
# Probability of Spam:  1.0
# Message:  ['u', 'were', 'outbid', 'by', 'simonwatson', 'on', 'the', 'shinco', 'dvd', 'plyr', '', 'bid', 'again', 'visit', 'sms', 'acsmsrewards', '', 'end', 'bid', 'notifications', 'reply', 'end', 'out']
# Probability of Spam:  1.0
# Message:  ['smsservices', 'for', 'yourinclusive', 'text', 'credits', 'pls', 'goto', 'wwwcomuknet', 'login', 'qxj', 'unsubscribe', 'with', 'stop', 'no', 'extra', 'charge', 'help', 'comuk', 'cm', 'ae']
# Probability of Spam:  1.0
# Message:  ['p', '', 'alfie', 'moons', 'children', 'in', 'need', 'song', 'on', 'ur', 'mob', 'tell', 'ur', 'ms', 'txt', 'tone', 'charity', 'to', '', 'for', 'nokias', 'or', 'poly', 'charity', 'for', 'polys', 'zed', '', 'profit', '', 'charity']
# Probability of Spam:  1.0
# Message:  ['u', 'have', 'a', 'secret', 'admirer', 'reveal', 'who', 'thinks', 'u', 'r', 'so', 'special', 'call', '', 'to', 'opt', 'out', 'reply', 'reveal', 'stop', '', 'per', 'msg', 'recd', 'cust', 'care', '']
# Probability of Spam:  1.0
# Message:  ['dear', 'voucher', 'holder', 'to', 'claim', 'this', 'weeks', 'offer', 'at', 'you', 'pc', 'please', 'go', 'to', 'httpwwwetlpcoukexpressoffer', 'tscs', 'apply', 'to', 'stop', 'texts', 'txt', 'stop', 'to', '']
# Probability of Spam:  1.0
# Message:  ['do', 'you', 'want', '', 'anytime', 'any', 'network', 'mins', '', 'text', 'and', 'a', 'new', 'video', 'phone', 'for', 'only', 'five', 'pounds', 'per', 'week', 'call', '', 'or', 'reply', 'for', 'delivery', 'tomorrow']
# Probability of Spam:  1.0
# Message:  ['we', 'tried', 'to', 'contact', 'you', 're', 'our', 'offer', 'of', 'new', 'video', 'phone', '', 'anytime', 'any', 'network', 'mins', 'half', 'price', 'rental', 'camcorder', 'call', '', 'or', 'reply', 'for', 'delivery', 'wed']
# Probability of Spam:  1.0
# Message:  ['last', 'chance', '', 'claim', 'ur', '', 'worth', 'of', 'discount', 'voucherstext', 'yes', 'to', '', 'nowsavamobmember', 'offers', 'mobile', 't', 'cs', '', '', 'sub', '', '', 'remove', 'txt', 'x', 'or', 'stop']
# Probability of Spam:  1.0
# Message:  ['urgent', 'call', '', 'from', 'your', 'landline', 'your', 'complimentary', '', 'ibiza', 'holiday', 'or', '', 'cash', 'await', 'collection', 'sae', 'tcs', 'po', 'box', '', 'sk', 'wp', '', 'ppm', '']
# Probability of Spam:  1.0
# Message:  ['todays', 'offer', 'claim', 'ur', '', 'worth', 'of', 'discount', 'vouchers', 'text', 'yes', 'to', '', 'now', 'savamob', 'member', 'offers', 'mobile', 't', 'cs', '', '', 'sub', '', '', 'unsub', 'reply', 'x']
# Probability of Spam:  1.0
# Message:  ['talk', 'sexy', 'make', 'new', 'friends', 'or', 'fall', 'in', 'love', 'in', 'the', 'worlds', 'most', 'discreet', 'text', 'dating', 'service', 'just', 'text', 'vip', 'to', '', 'and', 'see', 'who', 'you', 'could', 'meet']
# Probability of Spam:  1.0
# Message:  ['congratulations', 'ur', 'awarded', 'either', 'a', 'yrs', 'supply', 'of', 'cds', 'from', 'virgin', 'records', 'or', 'a', 'mystery', 'gift', 'guaranteed', 'call', '', 'tscs', 'wwwsmsconet', 'pm', 'approx', 'mins']
# Probability of Spam:  1.0
# Message:  ['private', 'your', '', 'account', 'statement', 'for', '', 'xxxxxx', 'shows', '', 'unredeemed', 's', 'i', 'm', 'points', 'call', '', 'identifier', 'code', '', 'expires', '']
# Probability of Spam:  1.0
# Message:  ['hello', 'we', 'need', 'some', 'posh', 'birds', 'and', 'chaps', 'to', 'user', 'trial', 'prods', 'for', 'champneys', 'can', 'i', 'put', 'you', 'down', 'i', 'need', 'your', 'address', 'and', 'dob', 'asap', 'ta', 'r']
# Probability of Spam:  1.0
# Message:  ['what', 'do', 'u', 'want', 'for', 'xmas', 'how', 'about', '', 'free', 'text', 'messages', '', 'a', 'new', 'video', 'phone', 'with', 'half', 'price', 'line', 'rental', 'call', 'free', 'now', 'on', '', '', 'to', 'find', 'out', 'more']
# Probability of Spam:  1.0
# Message:  ['shop', 'till', 'u', 'drop', 'is', 'it', 'you', 'either', 'k', 'k', '', 'cash', 'or', '', 'travel', 'voucher', 'call', 'now', '', 'ntt', 'po', 'box', 'crbt', 'fixedline', 'cost', 'ppm', 'mobile', 'vary']
# Probability of Spam:  1.0
# Message:  ['sunshine', 'quiz', 'wkly', 'q', 'win', 'a', 'top', 'sony', 'dvd', 'player', 'if', 'u', 'know', 'which', 'country', 'liverpool', 'played', 'in', 'mid', 'week', 'txt', 'ansr', 'to', '', '', 'sptyrone']
# Probability of Spam:  1.0
# Message:  ['u', 'have', 'a', 'secret', 'admirer', 'who', 'is', 'looking', '', 'make', 'contact', 'with', 'ufind', 'out', 'who', 'they', 'rreveal', 'who', 'thinks', 'ur', 'so', 'specialcall', 'on', '']
# Probability of Spam:  1.0
# Message:  ['u', 'have', 'a', 'secret', 'admirer', 'who', 'is', 'looking', '', 'make', 'contact', 'with', 'ufind', 'out', 'who', 'they', 'rreveal', 'who', 'thinks', 'ur', 'so', 'specialcall', 'on', 'stopsms']
# Probability of Spam:  1.0
# Message:  ['reminder', 'you', 'have', 'not', 'downloaded', 'the', 'content', 'you', 'have', 'already', 'paid', 'for', 'goto', 'httpdoit', 'mymoby', 'tv', 'to', 'collect', 'your', 'content']
# Probability of Spam:  1.0
# Message:  ['your', 'free', 'ringtone', 'is', 'waiting', 'to', 'be', 'collected', 'simply', 'text', 'the', 'password', 'mix', 'to', '', 'to', 'verify', 'get', 'usher', 'and', 'britney', 'fml', 'po', 'box', '', 'mk', 'h', 'ppw', '']
# Probability of Spam:  1.0
# Message:  ['all', 'the', 'lastest', 'from', 'stereophonics', 'marley', 'dizzee', 'racal', 'libertines', 'and', 'the', 'strokes', 'win', 'nookii', 'games', 'with', 'flirt', 'click', 'themob', 'wap', 'bookmark', 'or', 'text', 'wap', 'to', '']
# Probability of Spam:  1.0
# Message:  ['january', 'male', 'sale', 'hot', 'gay', 'chat', 'now', 'cheaper', 'call', '', 'national', 'rate', 'from', 'pmin', 'cheap', 'to', 'pmin', 'peak', 'to', 'stop', 'texts', 'call', '', 'pmin']
# Probability of Spam:  1.0
# Message:  ['money', 'you', 'r', 'a', 'lucky', 'winner', '', '', 'claim', 'your', 'prize', 'text', 'money', '', '', 'over', 'million', 'to', 'give', 'away', '', 'pptxnormal', 'text', 'rate', 'box', 'wtjy']
# Probability of Spam:  1.0
# Message:  ['dear', 'matthew', 'please', 'call', '', 'from', 'a', 'landline', 'your', 'complimentary', 'lux', 'tenerife', 'holiday', 'or', '', 'cash', 'await', 'collection', 'ppm', 'sae', 'tcs', 'box', 'skxh']
# Probability of Spam:  1.0
# Message:  ['urgent', 'call', '', 'from', 'landline', 'your', 'complimentary', '', 'tenerife', 'holiday', 'or', '', 'cash', 'await', 'collection', 'sae', 'tcs', 'box', '', 'hp', 'yf', 'ppm', '']
# Probability of Spam:  1.0
# Message:  ['how', 'about', 'getting', 'in', 'touch', 'with', 'folks', 'waiting', 'for', 'company', 'just', 'txt', 'back', 'your', 'name', 'and', 'age', 'to', 'opt', 'in', 'enjoy', 'the', 'community', 'psms']
# Probability of Spam:  1.0
# Message:  ['ur', 'cashbalance', 'is', 'currently', '', 'pounds', '', 'to', 'maximize', 'ur', 'cashin', 'now', 'send', 'go', 'to', '', 'only', 'pmsg', 'cc', '', 'po', 'box', '', 'tcrw']
# Probability of Spam:  1.0
# Message:  ['filthy', 'stories', 'and', 'girls', 'waiting', 'for', 'your']
# Probability of Spam:  1.0
# Message:  ['urgent', 'we', 'are', 'trying', 'to', 'contact', 'u', 'todays', 'draw', 'shows', 'that', 'you', 'have', 'won', 'a', '', 'prize', 'guaranteed', 'call', '', 'from', 'land', 'line', 'claim', 'm', 'validhrs', 'only']
# Probability of Spam:  1.0
# Message:  ['congrats', '', 'mobile', 'g', 'videophones', 'r', 'yours', 'call', '', 'now', 'videochat', 'wid', 'your', 'mates', 'play', 'java', 'games', 'dload', 'polyph', 'music', 'noline', 'rentl']
# Probability of Spam:  1.0
# Message:  ['please', 'call', 'our', 'customer', 'service', 'representative', 'on', 'freephone', '', '', '', 'between', 'ampm', 'as', 'you', 'have', 'won', 'a', 'guaranteed', '', 'cash', 'or', '', 'prize']
# Probability of Spam:  1.0
# Message:  ['panasonic', '', 'bluetoothhdset', 'free', 'nokia', 'free', 'motorola', 'free', '', 'doublemins', '', 'doubletxt', 'on', 'orange', 'contract', 'call', 'mobileupd', 'on', '', 'or', 'call', 'optout']
# Probability of Spam:  1.0
# Message:  ['free', 'for', 'st', 'week', 'no', 'nokia', 'tone', '', 'ur', 'mob', 'every', 'week', 'just', 'txt', 'nokia', 'to', '', 'get', 'txting', 'and', 'tell', 'ur', 'mates', 'wwwgetzedcouk', 'pobox', '', 'wwq', 'normptone', '']
# Probability of Spam:  1.0
# Message:  ['guess', 'what', 'somebody', 'you', 'know', 'secretly', 'fancies', 'you', 'wanna', 'find', 'out', 'who', 'it', 'is', 'give', 'us', 'a', 'call', 'on', '', 'from', 'landline', 'dateboxessexcmxn', 'pmin', '']
# Probability of Spam:  1.0
# Message:  ['we', 'know', 'someone', 'who', 'you', 'know', 'that', 'fancies', 'you', 'call', '', 'to', 'find', 'out', 'who', 'pobox', '', 'lshb', 'p']
# Probability of Spam:  1.0
# Message:  ['s', 'flirting', 'now', 'txt', 'girl', 'or', 'bloke', '', 'ur', 'name', '', 'age', 'eg', 'girl', 'zoe', '', 'to', '', 'to', 'join', 'and', 'get', 'chatting']
# Probability of Spam:  1.0
# Message:  ['', 'days', 'to', 'euro', 'kickoff', 'u', 'will', 'be', 'kept', 'informed', 'of', 'all', 'the', 'latest', 'news', 'and', 'results', 'daily', 'unsubscribe', 'send', 'get', 'euro', 'stop', 'to', '']
# Probability of Spam:  1.0
# Message:  ['eastenders', 'tv', 'quiz', 'what', 'flower', 'does', 'dot', 'compare', 'herself', 'to', 'd', 'violet', 'e', 'tulip', 'f', 'lily', 'txt', 'd', 'e', 'or', 'f', 'to', '', 'now', '', 'chance', '', 'win', '', 'cash', 'wkentp']
# Probability of Spam:  1.0
# Message:  ['we', 'have', 'new', 'local', 'dates', 'in', 'your', 'area', '', 'lots', 'of', 'new', 'people', 'registered', 'in', 'your', 'area', 'reply', 'date', 'to', 'start', 'now', '', 'only', 'wwwflirtpartyus', 'replys']
# Probability of Spam:  1.0
# Message:  ['someone', 'u', 'know', 'has', 'asked', 'our', 'dating', 'service', '', 'contact', 'you', 'cant', 'guess', 'who', 'call', '', 'now', 'all', 'will', 'be', 'revealed', 'po', 'box', 'm', 'wu']
# Probability of Spam:  1.0
# Message:  ['urgent', 'we', 'are', 'trying', 'to', 'contact', 'u', 'todays', 'draw', 'shows', 'that', 'you', 'have', 'won', 'a', '', 'prize', 'guaranteed', 'call', '', 'from', 'land', 'line', 'claim', 'c', 'validhrs', 'only']
# Probability of Spam:  1.0
# Message:  ['dear', 'uve', 'been', 'invited', 'to', 'xchat', 'this', 'is', 'our', 'final', 'attempt', 'to', 'contact', 'u', 'txt', 'chat', 'to', '']
# Probability of Spam:  1.0
# Message:  ['you', 'are', 'awarded', 'a', 'sipix', 'digital', 'camera', 'call', '', 'from', 'landline', 'delivery', 'within', 'days', 't', 'cs', 'box', 'mbp', 'yr', 'warranty', 'ppm', '', '', 'p', 'p']
# Probability of Spam:  1.0
# Message:  ['win', 'urgent', 'your', 'mobile', 'number', 'has', 'been', 'awarded', 'with', 'a', '', 'prize', 'guaranteed', 'call', '', 'from', 'land', 'line', 'claim', '', 'valid', 'hrs', 'only', 'ppm']
# Probability of Spam:  1.0
# Message:  ['dear', 'subscriber', 'ur', 'draw', '', '', 'gift', 'voucher', 'will', 'b', 'entered', 'on', 'receipt', 'of', 'a', 'correct', 'ans', 'when', 'was', 'elvis', 'presleys', 'birthday', 'txt', 'answer', 'to', '']
# Probability of Spam:  1.0
# Message:  ['message', 'important', 'information', 'for', 'o', 'user', 'today', 'is', 'your', 'lucky', 'day', '', 'find', 'out', 'why', 'log', 'onto', 'httpwwwurawinnercom', 'there', 'is', 'a', 'fantastic', 'surprise', 'awaiting', 'you']
# Probability of Spam:  1.0
# Message:  ['', 'you', 'have', 'won', 'a', '', 'price', 'to', 'claim', 'call', '']
# Probability of Spam:  1.0
# Message:  ['bored', 'of', 'speed', 'dating', 'try', 'speedchat', 'txt', 'speedchat', 'to', '', 'if', 'you', 'dont', 'like', 'em', 'txt', 'swap', 'and', 'get', 'a', 'new', 'chatter', 'chat', 'poboxwwq', 'pmsg', 'rcd', '']
# Probability of Spam:  1.0
# Message:  ['do', 'you', 'want', '', 'anytime', 'any', 'network', 'mins', '', 'text', 'and', 'a', 'new', 'video', 'phone', 'for', 'only', 'five', 'pounds', 'per', 'week', 'call', '', 'now', 'or', 'reply', 'for', 'delivery', 'tomorrow']
# Probability of Spam:  1.0
# Message:  ['for', 'taking', 'part', 'in', 'our', 'mobile', 'survey', 'yesterday', 'you', 'can', 'now', 'have', '', 'texts', '', 'use', 'however', 'you', 'wish', '', 'get', 'txts', 'just', 'send', 'txt', 'to', '', 'tc', 'wwwtxtcom', 'p']
# Probability of Spam:  1.0
# Message:  ['ur', 'hmv', 'quiz', 'cashbalance', 'is', 'currently', '', '', 'to', 'maximize', 'ur', 'cashin', 'now', 'send', 'hmv', 'to', '', 'only', 'pmsg']
# Probability of Spam:  1.0
# Message:  ['dont', 'forget', 'you', 'can', 'place', 'as', 'many', 'free', 'requests', 'with', 'stchoicecouk', 'as', 'you', 'wish', 'for', 'more', 'information', 'call', '']
# Probability of Spam:  1.0
# Message:  ['i', 'dont', 'know', 'u', 'and', 'u', 'dont', 'know', 'me', 'send', 'chat', 'to', '', 'now', 'and', 'lets', 'find', 'each', 'other', 'only', 'pmsg', 'rcvd', 'hgsuitelandsrowwjhl', 'ldn', '', 'years', 'or', 'over']
# Probability of Spam:  1.0
# Message:  ['thank', 'you', 'winner', 'notified', 'by', 'sms', 'good', 'luck', 'no', 'future', 'marketing', 'reply', 'stop', 'to', '', 'customer', 'services', '']
# Probability of Spam:  1.0
# Message:  ['s', 'of', 'girls', 'many', 'local', '', 'u', 'who', 'r', 'virgins', '', 'this', '', 'r', 'ready', '', 'fil', 'ur', 'every', 'sexual', 'need', 'can', 'u', 'fil', 'theirs', 'text', 'cute', 'to', 'p', 'm']
# Probability of Spam:  1.0
# Message:  ['free', 'entry', 'in', '', 'a', 'wkly', 'comp', 'to', 'win', 'fa', 'cup', 'final', 'tkts', 'st', 'may', '', 'text', 'fa', 'to', '', 'to', 'receive', 'entry', 'questionstd', 'txt', 'ratetcs', 'apply', 'overs']
# Probability of Spam:  1.0
# Message:  ['got', 'what', 'it', 'takes', '', 'take', 'part', 'in', 'the', 'wrc', 'rally', 'in', 'oz', 'u', 'can', 'with', 'lucozade', 'energy', 'text', 'rally', 'le', 'to', '', 'p', 'see', 'packs', 'or', 'lucozadecoukwrc', '', 'itcould', 'be', 'u']
# Probability of Spam:  1.0
# Message:  ['sex', 'up', 'ur', 'mobile', 'with', 'a', 'free', 'sexy', 'pic', 'of', 'jordan', 'just', 'text', 'babe', 'to', '', 'then', 'every', 'wk', 'get', 'a', 'sexy', 'celeb', 'pocketbabecouk', '', 'more', 'pics', '', 'wk', '']
# Probability of Spam:  1.0
# Message:  ['you', 'have', '', 'new', 'voicemail', 'please', 'call', '']
# Probability of Spam:  1.0
# Message:  ['win', 'a', 'year', 'supply', 'of', 'cds', '', 'a', 'store', 'of', 'ur', 'choice', 'worth', '', '', 'enter', 'our', '', 'weekly', 'draw', 'txt', 'music', 'to', '', 'tscs', 'wwwldewcomsubswinppmx']
# Probability of Spam:  1.0
# Message:  ['as', 'a', 'sim', 'subscriber', 'you', 'are', 'selected', 'to', 'receive', 'a', 'bonus', 'get', 'it', 'delivered', 'to', 'your', 'door', 'txt', 'the', 'word', 'ok', 'to', 'no', '', 'to', 'claim', 'pmsg', 'exp', 'apr']
# Probability of Spam:  1.0
# Message:  ['you', 'have', '', 'new', 'voicemail', 'please', 'call', '']
# Probability of Spam:  1.0
# Message:  ['no', '', 'nokia', 'tone', '', 'ur', 'mob', 'every', 'week', 'just', 'txt', 'nok', 'to', '', 'st', 'tone', 'free', '', 'so', 'get', 'txtin', 'now', 'and', 'tell', 'ur', 'friends', 'ptone', '', 'reply', 'hl', 'info']
# Probability of Spam:  1.0
# Message:  ['you', 'are', 'a', 'winner', 'u', 'have', 'been', 'specially', 'selected', '', 'receive', '', 'cash', 'or', 'a', '', 'holiday', 'flights', 'inc', 'speak', 'to', 'a', 'live', 'operator', '', 'claim', '']
# Probability of Spam:  1.0
# Message:  ['reply', 'with', 'your', 'name', 'and', 'address', 'and', 'you', 'will', 'receive', 'by', 'post', 'a', 'weeks', 'completely', 'free', 'accommodation', 'at', 'various', 'global', 'locations', 'wwwphbcom', 'php']
# Probability of Spam:  1.0
# Message:  ['free', 'entry', 'into', 'our', '', 'weekly', 'comp', 'just', 'send', 'the', 'word', 'enter', 'to', '', 'now', '', 'tc', 'wwwtextcompcom', 'cust', 'care', '']
# Probability of Spam:  1.0
# Message:  ['please', 'call', '', 'immediately', 'as', 'there', 'is', 'an', 'urgent', 'message', 'waiting', 'for', 'you']
# Probability of Spam:  0.9999997859830869
# Message:  ['hungry', 'gay', 'guys', 'feeling', 'hungry', 'and', 'up', '', 'it', 'now', 'call', '', 'just', 'pmin', 'to', 'stop', 'texts', 'call', '', 'pmin']
# Probability of Spam:  1.0
# Message:  ['can', 'u', 'get', '', 'phone', 'now', 'i', 'wanna', 'chat', '', 'set', 'up', 'meet', 'call', 'me', 'now', 'on', '', 'u', 'can', 'cum', 'here', 'moro', 'luv', 'jane', 'xx', 'callsminmoremobsemspoboxpowa']
# Probability of Spam:  1.0
# Message:  ['network', 'operator', 'the', 'service', 'is', 'free', 'for', 't', '', 'cs', 'visit', 'biz']
# Probability of Spam:  1.0
# Message:  ['enjoy', 'the', 'jamster', 'videosound', 'gold', 'club', 'with', 'your', 'credits', 'for', '', 'new', 'videosounds', 'logosmusicnews', 'get', 'more', 'fun', 'from', 'jamstercouk', 'only', 'help', 'call', '']
# Probability of Spam:  1.0
# Message:  ['get', '', 'lions', 'england', 'tone', 'reply', 'lionm', '', 'mono', 'or', 'lionp', '', 'poly', '', 'more', 'go', '', 'wwwringtonescouk', 'the', 'original', 'n', 'best', 'tones', 'gbp', 'network', 'operator', 'rates', 'apply']
# Probability of Spam:  1.0
# Message:  ['win', 'the', 'newest', 'harry', 'potter', 'and', 'the', 'order', 'of', 'the', 'phoenix', 'book', '', 'reply', 'harry', 'answer', '', 'questions', '', 'chance', 'to', 'be', 'the', 'first', 'among', 'readers']
# Probability of Spam:  1.0
# Message:  ['ur', 'balance', 'is', 'now', '', 'ur', 'next', 'question', 'is', 'who', 'sang', 'uptown', 'girl', 'in', 'the', 's', '', '', 'answer', 'txt', 'ur', 'answer', 'to', '', 'good', 'luck']
# Probability of Spam:  1.0
# Message:  ['freeday', 'sexy', 'st', 'georges', 'day', 'pic', 'of', 'jordantxt', 'pic', 'to', '', 'dont', 'miss', 'out', 'then', 'every', 'wk', 'a', 'saucy', 'celeb', 'more', 'pics', 'c', 'pocketbabecouk', '', 'wk']
# Probability of Spam:  1.0
# Message:  ['hot', 'live', 'fantasies', 'call', 'now', '', 'just', 'p', 'per', 'min', 'ntt', 'ltd', 'po', 'box', '', 'croydon', 'cr', 'wb', 'k']
# Probability of Spam:  1.0
# Message:  ['bears', 'pic', 'nick', 'and', 'tom', 'pete', 'and', '', 'dick', 'in', 'fact', 'all', 'types', 'try', 'gay', 'chat', 'with', 'photo', 'upload', 'call', '', 'pmin', '', 'stop', 'texts', 'call', '']
# Probability of Spam:  1.0
# Message:  ['', 'new', 'mobiles', 'from', '', 'must', 'go', 'txt', 'nokia', 'to', 'no', '', '', 'collect', 'yours', 'todayfrom', 'only', '', 'wwwtcbiz', 'optout', 'gbpmtmsg', 'txtauction']
# Probability of Spam:  1.0
# Message:  ['double', 'mins', '', 'double', 'txt', '', '', 'price', 'linerental', 'on', 'latest', 'orange', 'bluetooth', 'mobiles', 'call', 'mobileupd', 'for', 'the', 'very', 'latest', 'offers', '', 'or', 'calloptoutlf']
# Probability of Spam:  1.0
# Message:  ['no', '', 'nokia', 'tone', '', 'ur', 'mob', 'every', 'week', 'just', 'txt', 'nok', 'to', '', 'st', 'tone', 'free', '', 'so', 'get', 'txtin', 'now', 'and', 'tell', 'ur', 'friends', 'ptone', '', 'reply', 'hl', 'info']
# Probability of Spam:  1.0
# Message:  ['urgent', 'important', 'information', 'for', 'o', 'user', 'today', 'is', 'your', 'lucky', 'day', '', 'find', 'out', 'why', 'log', 'onto', 'httpwwwurawinnercom', 'there', 'is', 'a', 'fantastic', 'surprise', 'awaiting', 'for', 'you']
# Probability of Spam:  1.0
# Message:  ['dear', 'uve', 'been', 'invited', 'to', 'xchat', 'this', 'is', 'our', 'final', 'attempt', 'to', 'contact', 'u', 'txt', 'chat', 'to', '', 'pmsgrcvdhgsuitelandsrowwjhl', 'ldn', '', 'yrs']
# Probability of Spam:  1.0
# Message:  ['congratulations', 'ur', 'awarded', 'either', '', 'of', 'cd', 'gift', 'vouchers', '', 'free', 'entry', '', 'our', '', 'weekly', 'draw', 'txt', 'music', 'to', '', 'tncs', 'wwwldewcom', '', 'winppmxage']
# Probability of Spam:  1.0
# Message:  ['for', 'sale', '', 'arsenal', 'dartboard', 'good', 'condition', 'but', 'no', 'doubles', 'or', 'trebles']
# Probability of Spam:  1.0
# Message:  ['free', 'st', 'week', 'entry', '', 'textpod', '', 'a', 'chance', '', 'win', 'gb', 'ipod', 'or', '', 'cash', 'every', 'wk', 'txt', 'pod', 'to', '', 'tscs', 'wwwtextpodnet', 'custcare', '']
# Probability of Spam:  1.0
# Message:  ['as', 'a', 'registered', 'optin', 'subscriber', 'ur', 'draw', '', '', 'gift', 'voucher', 'will', 'be', 'entered', 'on', 'receipt', 'of', 'a', 'correct', 'ans', 'to', '', 'whats', 'no', 'in', 'the', 'bbc', 'charts']
# Probability of Spam:  1.0
# Message:  ['summers', 'finally', 'here', 'fancy', 'a', 'chat', 'or', 'flirt', 'with', 'sexy', 'singles', 'in', 'yr', 'area', 'to', 'get', 'matched', 'up', 'just', 'reply', 'summer', 'now', 'free', '', 'join', 'optout', 'txt', 'stop', 'help']
# Probability of Spam:  1.0
# Message:  ['claire', 'here', 'am', 'havin', 'borin', 'time', '', 'am', 'now', 'alone', 'u', 'wanna', 'cum', 'over', 'nite', 'chat', 'now', '', 'hope', '', 'c', 'u', 'luv', 'claire', 'xx', 'callsminmoremobsemspoboxpowa']
# Probability of Spam:  1.0
# Message:  ['bought', 'one', 'ringtone', 'and', 'now', 'getting', 'texts', 'costing', '', 'pound', 'offering', 'more', 'tones', 'etc']
# Probability of Spam:  1.0
# Message:  ['', 'urgent', 'your', 'mobile', 'no', 'xxxxxxxxx', 'won', 'a', '', 'bonus', 'caller', 'prize', 'on', '', 'this', 'is', 'the', 'nd', 'attempt', 'to', 'reach', 'you', 'call', '', 'asap']
# Probability of Spam:  1.0
# Message:  ['you', '', 'are', 'guaranteed', 'the', 'latests', 'nokia', 'phone', 'a', 'gb', 'ipod', 'mp', 'player', 'or', 'a', '', 'prize', 'txt', 'wordcollect', 'to', 'no', 'tcllc', 'nyusa', 'pmt', 'msgrcvd']
# Probability of Spam:  1.0
# Message:  ['hi', 'its', 'lucy', 'hubby', 'at', 'meetins', 'all', 'day', 'fri', '', 'i', 'will', 'b', 'alone', 'at', 'hotel', 'u', 'fancy', 'cumin', 'over', 'pls', 'leave', 'msg', 'day', '', 'lucy', 'x', 'callsminmobsmorelkpoboxhpfl']
# Probability of Spam:  1.0
# ...
# Probability of Spam:  1.0
# Message:  ['do', 'you', 'want', 'a', 'new', 'nokia', 'i', 'colour', 'phone', 'deliveredtomorrow', 'with', '', 'free', 'minutes', 'to', 'any', 'mobile', '', '', 'free', 'texts', '', 'free', 'camcorder', 'reply', 'or', 'call', '']
# Probability of Spam:  1.0
# Message:  ['life', 'has', 'never', 'been', 'this', 'much', 'fun', 'and', 'great', 'until', 'you', 'came', 'in', 'you', 'made', 'it', 'truly', 'special', 'for', 'me', 'i', 'wont', 'forget', 'you', 'enjoy', '', 'one', 'gbpsms']
# Probability of Spam:  1.0
# Message:  ['do', 'you', 'want', 'a', 'new', 'video', 'phone', '', 'anytime', 'any', 'network', 'mins', '', 'inclusive', 'video', 'calls', 'and', 'downloads', '', 'per', 'week', 'free', 'deltomorrow', 'call', '', 'or', 'reply', 'now']
# Probability of Spam:  1.0
# Message:  ['as', 'a', 'valued', 'customer', 'i', 'am', 'pleased', 'to', 'advise', 'you', 'that', 'following', 'recent', 'review', 'of', 'your', 'mob', 'no', 'you', 'are', 'awarded', 'with', 'a', '', 'bonus', 'prize', 'call', '']
# Probability of Spam:  1.0
# Message:  ['welcome', 'please', 'reply', 'with', 'your', 'age', 'and', 'gender', 'to', 'begin', 'eg', 'm']
# Probability of Spam:  1.0
# Message:  ['freemsg', 'month', 'unlimited', 'free', 'calls', 'activate', 'smartcall', 'txt', 'call', 'to', 'no', '', 'subscriptngbpwk', 'unlimited', 'calls', 'help', '', 'stoptxt', 'stop', 'landlineonly']
# Probability of Spam:  1.0
# Message:  ['had', 'your', 'mobile', '', 'mths', 'update', 'to', 'latest', 'orange', 'cameravideo', 'phones', 'for', 'free', 'save', 's', 'with', 'free', 'textsweekend', 'calls', 'text', 'yes', 'for', 'a', 'callback', 'orno', 'to', 'opt', 'out']
# Probability of Spam:  1.0
# Message:  ['am', 'new', '', 'club', '', 'dont', 'fink', 'we', 'met', 'yet', 'will', 'b', 'gr', '', 'c', 'u', 'please', 'leave', 'msg', 'day', 'wiv', 'ur', 'area', '', 'reply', 'promised', 'carlie', 'x', 'callsminmobsmore', 'lkpoboxhpfl']
# Probability of Spam:  1.0
# Message:  ['camera', '', 'you', 'are', 'awarded', 'a', 'sipix', 'digital', 'camera', 'call', '', 'fromm', 'landline', 'delivery', 'within', '', 'days']
# Probability of Spam:  1.0
# Message:  ['get', 'a', 'free', 'mobile', 'video', 'player', 'free', 'movie', 'to', 'collect', 'text', 'go', 'to', '', 'its', 'free', 'extra', 'films', 'can', 'be', 'ordered', 'ts', 'and', 'cs', 'apply', '', 'yrs', 'only']
# Probability of Spam:  1.0
# Message:  ['save', 'money', 'on', 'wedding', 'lingerie', 'at', 'wwwbridalpetticoatdreamscouk', 'choose', 'from', 'a', 'superb', 'selection', 'with', 'national', 'delivery', 'brought', 'to', 'you', 'by', 'weddingfriend']
# Probability of Spam:  1.0
# Message:  ['not', 'heard', 'from', 'u', 'a', 'while', 'call', 'me', 'now', 'am', 'here', 'all', 'night', 'with', 'just', 'my', 'knickers', 'on', 'make', 'me', 'beg', 'for', 'it', 'like', 'u', 'did', 'last', 'time', '', 'xx', 'luv', 'nikiyunet']
# Probability of Spam:  1.0
# Message:  ['bloomberg', 'message', 'center', '', 'why', 'wait', 'apply', 'for', 'your', 'future', 'httpcareers', 'bloombergcom']
# Probability of Spam:  1.0
# Message:  ['urgent', 'we', 'are', 'trying', 'to', 'contact', 'u', 'todays', 'draw', 'shows', 'that', 'you', 'have', 'won', 'a', '', 'prize', 'guaranteed', 'call', '', 'from', 'land', 'line', 'claim', 'm', 'validhrs', 'only']
# Probability of Spam:  1.0
# Message:  ['do', 'you', 'want', 'a', 'new', 'video', 'phone', 'anytime', 'any', 'network', 'mins', '', 'text', 'for', 'only', 'five', 'pounds', 'per', 'week', 'call', '', 'now', 'or', 'reply', 'for', 'delivery', 'tomorrow']
# Probability of Spam:  1.0
# Message:  ['you', 'are', 'being', 'contacted', 'by', 'our', 'dating', 'service', 'by', 'someone', 'you', 'know', 'to', 'find', 'out', 'who', 'it', 'is', 'call', 'from', 'a', 'land', 'line', '', 'poboxwtgp']
# Probability of Spam:  1.0
# Message:  ['wan', 'win', 'a', 'meetgreet', 'with', 'westlife', '', 'u', 'or', 'a', 'm', 'they', 'are', 'currently', 'on', 'what', 'tour', 'unbreakable', 'untamed', 'unkempt', 'text', '', 'or', '', 'to', '', 'cost', 'p', 'std', 'text']
# Probability of Spam:  1.0
# Message:  ['dorothykiefercom', 'bank', 'of', 'granite', 'issues', 'strongbuy', 'explosive', 'pick', 'for', 'our', 'members', 'up', 'over', '', '', 'nasdaq', 'symbol', 'cdgt', 'that', 'is', 'a', '', 'per']
# Probability of Spam:  1.0
# Message:  ['you', 'are', 'a', '', 'winner', 'or', 'guaranteed', 'caller', 'prize', 'this', 'is', 'our', 'final', 'attempt', 'to', 'contact', 'you', 'to', 'claim', 'call', '', 'now', 'ppmpoboxbhambxe']
# Probability of Spam:  1.0
# Message:  ['xmas', '', 'new', 'years', 'eve', 'tickets', 'are', 'now', 'on', 'sale', 'from', 'the', 'club', 'during', 'the', 'day', 'from', 'am', 'till', 'pm', 'and', 'on', 'thurs', 'fri', '', 'sat', 'night', 'this', 'week', 'theyre', 'selling', 'fast']
# Probability of Spam:  1.0
# Message:  ['rock', 'yr', 'chik', 'get', 's', 'of', 'filthy', 'films', 'xxx', 'pics', 'on', 'yr', 'phone', 'now', 'rply', 'filth', 'to', '', 'saristar', 'ltd', 'e', 'yt', '', 'p', 'per', '', 'days', 'stop', 'cancel']
# Probability of Spam:  1.0
# Message:  ['from', 'next', 'month', 'get', 'upto', '', 'more', 'calls', '', 'ur', 'standard', 'network', 'charge', '', 'activate', 'call', '', 'c', 'wirenet', 'stterms', 'pobox', 'm', 'uz', 'cost', '', 'min', 'mobcudb', 'more']
# Probability of Spam:  1.0
# Message:  ['urgent', 'we', 'are', 'trying', 'to', 'contact', 'u', 'todays', 'draw', 'shows', 'that', 'you', 'have', 'won', 'a', '', 'prize', 'guaranteed', 'call', '', 'from', 'land', 'line', 'claim', 'j', 'po', 'boxcpm']
# Probability of Spam:  1.0
# Message:  ['text', 'banneduk', 'to', '', 'to', 'see', 'cost', 'p', 'textoperator', 'gga', '', 'xxx']
# Probability of Spam:  1.0
# Message:  ['auction', 'round', '', 'the', 'highest', 'bid', 'is', 'now', '', 'next', 'maximum', 'bid', 'is', '', 'to', 'bid', 'send', 'bids', 'e', 'g', '', 'to', 'bid', '', 'to', '', 'good', 'luck']
# Probability of Spam:  1.0
# Message:  ['collect', 'your', 'valentines', 'weekend', 'to', 'paris', 'inc', 'flight', '', 'hotel', '', '', 'prize', 'guaranteed', 'text', 'paris', 'to', 'no', '', 'wwwrtfsphostingcom']
# Probability of Spam:  1.0
# Message:  ['customer', 'loyalty', 'offerthe', 'new', 'nokia', 'mobile', 'from', 'only', '', 'at', 'txtauction', 'txt', 'word', 'start', 'to', 'no', '', '', 'get', 'yours', 'now', 'tctxt', 'tc', 'pmtmsg']
# Probability of Spam:  1.0
# Message:  ['you', 'wont', 'believe', 'it', 'but', 'its', 'true', 'its', 'incredible', 'txts', 'reply', 'g', 'now', 'to', 'learn', 'truly', 'amazing', 'things', 'that', 'will', 'blow', 'your', 'mind', 'from', 'ofwd', 'only', 'ptxt']
# Probability of Spam:  1.0
# Message:  ['hi', '', 'ibh', 'customer', 'loyalty', 'offer', 'the', 'new', 'nokia', 'mobile', 'from', 'only', '', 'at', 'txtauctiontxt', 'wordstart', 'to', 'no', '', 'get', 'yours', 'nowt']
# Probability of Spam:  1.0
# Message:  ['i', 'am', 'hot', 'n', 'horny', 'and', 'willing', 'i', 'live', 'local', 'to', 'you', '', 'text', 'a', 'reply', 'to', 'hear', 'strt', 'back', 'from', 'me', 'p', 'per', 'msg', 'netcollex', 'ltdhelpdesk', '', 'reply', 'stop', 'to', 'end']
# Probability of Spam:  1.0
# Message:  ['do', 'you', 'want', 'a', 'new', 'nokia', 'i', 'colour', 'phone', 'delivered', 'tomorrow', 'with', '', 'free', 'minutes', 'to', 'any', 'mobile', '', '', 'free', 'text', '', 'free', 'camcorder', 'reply', 'or', 'call', '']
# Probability of Spam:  1.0
# Message:  ['congratulations', 'youve', 'won', 'youre', 'a', 'winner', 'in', 'our', 'august', '', 'prize', 'draw', 'call', '', 'now', 'prize', 'code', '']
# Probability of Spam:  1.0
# Message:  ['', 'p', '', 'alfie', 'moons', 'children', 'in', 'need', 'song', 'on', 'ur', 'mob', 'tell', 'ur', 'ms', 'txt', 'tone', 'charity', 'to', '', 'for', 'nokias', 'or', 'poly', 'charity', 'for', 'polys', 'zed', '', 'profit', '', 'charity']
# Probability of Spam:  1.0
# Message:  ['get', 'the', 'official', 'england', 'poly', 'ringtone', 'or', 'colour', 'flag', 'on', 'yer', 'mobile', 'for', 'tonights', 'game', 'text', 'tone', 'or', 'flag', 'to', '', 'optout', 'txt', 'eng', 'stop', 'box', 'wwx', '']
# Probability of Spam:  1.0
# Message:  ['customer', 'service', 'announcement', 'we', 'recently', 'tried', 'to', 'make', 'a', 'delivery', 'to', 'you', 'but', 'were', 'unable', 'to', 'do', 'so', 'please', 'call', '', 'to', 'reschedule', 'ref']
# Probability of Spam:  1.0
# Message:  ['you', 'can', 'stop', 'further', 'club', 'tones', 'by', 'replying', 'stop', 'mix', 'see', 'mytonecomenjoy', 'html', 'for', 'terms', 'club', 'tones', 'cost', 'gbpweek', 'mfl', 'po', 'box', '', 'mk', 'wt', '']
# Probability of Spam:  1.0
# Message:  ['wamma', 'get', 'laidwant', 'real', 'doggin', 'locations', 'sent', 'direct', 'to', 'your', 'mobile', 'join', 'the', 'uks', 'largest', 'dogging', 'network', 'txt', 'dogs', 'to', '', 'nownyt', 'eca', 'lp', 'msg']
# Probability of Spam:  1.0
# Message:  ['you', 'have', 'won', 'a', 'nokia', 'i', 'this', 'is', 'what', 'you', 'get', 'when', 'you', 'win', 'our', 'free', 'auction', 'to', 'take', 'part', 'send', 'nokia', 'to', '', 'now', 'hgsuitelands', 'rowwjhl', '']
# Probability of Spam:  1.0
# Message:  ['promotion', 'number', '', '', 'ur', 'awarded', 'a', 'city', 'break', 'and', 'could', 'win', 'a', '', 'summer', 'shopping', 'spree', 'every', 'wk', 'txt', 'store', 'to', '', '', 'skilgme', 'tscswinawkage', 'perwksub']
# Probability of Spam:  1.0
# Message:  ['you', 'are', 'a', 'winner', 'you', 'have', 'been', 'specially', 'selected', 'to', 'receive', '', 'cash', 'or', 'a', '', 'award', 'speak', 'to', 'a', 'live', 'operator', 'to', 'claim', 'call', 'ampm', 'cost', 'p']
# Probability of Spam:  1.0
# Message:  ['free', 'top', 'ringtone', 'sub', 'to', 'weekly', 'ringtoneget', 'st', 'week', 'freesend', 'subpoly', 'to', '', 'per', 'weekstop', 'sms']
# Probability of Spam:  1.0
# Message:  ['thanks', 'for', 'your', 'ringtone', 'order', 'reference', 'number', 'x', 'your', 'mobile', 'will', 'be', 'charged', '', 'should', 'your', 'tone', 'not', 'arrive', 'please', 'call', 'customer', 'services', '', 'from', 'colourredtextcolourtxtstar']
# Probability of Spam:  1.0
# Message:  ['hi', 'there', 'nights', 'ur', 'lucky', 'night', 'uve', 'been', 'invited', '', 'xchat', 'the', 'uks', 'wildest', 'chat', 'txt', 'chat', 'to', '', 'now', 'pmsgrcvdhgsuitelandsrowwjhl', 'ldn', 'yrs']
# Probability of Spam:  1.0
# Message:  ['', 'tfp']
# Probability of Spam:  1.0
# Message:  ['dear', 'voucher', 'holder', '', 'claim', 'your', 'st', 'class', 'airport', 'lounge', 'passes', 'when', 'using', 'your', 'holiday', 'voucher', 'call', '', 'when', 'booking', 'quote', 'st', 'class', 'x', '']
# Probability of Spam:  1.0
# Message:  ['bloomberg', 'message', 'center', '', 'why', 'wait', 'apply', 'for', 'your', 'future', 'httpcareers', 'bloombergcom']
# Probability of Spam:  1.0
# Message:  ['yes', 'the', 'only', 'place', 'in', 'town', 'to', 'meet', 'exciting', 'adult', 'singles', 'is', 'now', 'in', 'the', 'uk', 'txt', 'chat', 'to', '', 'now', 'pmsg']
# Probability of Spam:  1.0
# Message:  ['free', 'for', 'st', 'week', 'no', 'nokia', 'tone', '', 'ur', 'mob', 'every', 'week', 'just', 'txt', 'nokia', 'to', '', 'get', 'txting', 'and', 'tell', 'ur', 'mates', 'wwwgetzedcouk', 'pobox', '', 'wwq', 'normptone', '']
# Probability of Spam:  1.0
# Message:  ['someone', 'u', 'know', 'has', 'asked', 'our', 'dating', 'service', '', 'contact', 'you', 'cant', 'guess', 'who', 'call', '', 'now', 'all', 'will', 'be', 'revealed', 'pobox', '', 'sxy', 'p']
# Probability of Spam:  1.0
# Message:  ['mila', 'age', 'blonde', 'new', 'in', 'uk', 'i', 'look', 'sex', 'with', 'uk', 'guys', 'if', 'u', 'like', 'fun', 'with', 'me', 'text', 'mtalk', 'to', '', '', 'pptxt', 'st', 'free', '', 'increments', 'help']
# Probability of Spam:  1.0
# Message:  ['claim', 'a', '', 'shopping', 'spree', 'just', 'call', '', 'now', 'have', 'you', 'won', 'mobstorequizppm']
# Probability of Spam:  1.0
# Message:  ['want', 'to', 'funk', 'up', 'ur', 'fone', 'with', 'a', 'weekly', 'new', 'tone', 'reply', 'tonesu', '', 'this', 'text', 'wwwringtonescouk', 'the', 'original', 'n', 'best', 'tones', 'gbp', 'network', 'operator', 'rates', 'apply']
# Probability of Spam:  1.0
# Message:  ['twinks', 'bears', 'scallies', 'skins', 'and', 'jocks', 'are', 'calling', 'now', 'dont', 'miss', 'the', 'weekends', 'fun', 'call', '', 'at', 'pmin', '', 'stop', 'texts', 'call', 'nat', 'rate']
# Probability of Spam:  1.0
# Message:  ['we', 'tried', 'to', 'contact', 'you', 're', 'your', 'reply', 'to', 'our', 'offer', 'of', 'a', 'video', 'handset', '', 'anytime', 'any', 'networks', 'mins', 'unlimited', 'text', 'camcorder', 'reply', 'or', 'call', '', 'now']
# Probability of Spam:  1.0
# Message:  ['urgent', 'we', 'are', 'trying', 'to', 'contact', 'you', 'last', 'weekends', 'draw', 'shows', 'that', 'you', 'have', 'won', 'a', '', 'prize', 'guaranteed', 'call', '', 'claim', 'code', 'k', 'valid', 'hours', 'only']
# Probability of Spam:  1.0
# Message:  ['', 'xmas', 'iscoming', '', 'ur', 'awarded', 'either', '', 'cd', 'gift', 'vouchers', '', 'free', 'entry', '', 'r', '', 'weekly', 'draw', 'txt', 'music', 'to', '', 'tnc']
# Probability of Spam:  1.0
# Message:  ['congratulations', 'u', 'can', 'claim', '', 'vip', 'row', 'a', 'tickets', '', 'c', 'blu', 'in', 'concert', 'in', 'november', 'or', 'blu', 'gift', 'guaranteed', 'call', '', 'to', 'claim', 'tscs', 'wwwsmsconet', 'costmax']
# Probability of Spam:  1.0
# Message:  ['fantasy', 'football', 'is', 'back', 'on', 'your', 'tv', 'go', 'to', 'sky', 'gamestar', 'on', 'sky', 'active', 'and', 'play', 'k', 'dream', 'team', 'scoring', 'starts', 'on', 'saturday', 'so', 'register', 'nowsky', 'opt', 'out', 'to', '']
# Probability of Spam:  1.0
# Message:  ['free', 'msg', 'single', 'find', 'a', 'partner', 'in', 'your', 'area', 's', 'of', 'real', 'people', 'are', 'waiting', 'to', 'chat', 'nowsend', 'chat', 'to', 'cncl', 'send', 'stopcs', '', 'per', 'msg']
# Probability of Spam:  1.0
# Message:  ['win', 'the', 'newest', 'harry', 'potter', 'and', 'the', 'order', 'of', 'the', 'phoenix', 'book', '', 'reply', 'harry', 'answer', '', 'questions', '', 'chance', 'to', 'be', 'the', 'first', 'among', 'readers']
# Probability of Spam:  1.0
# Message:  ['free', 'msg', 'ringtonefrom', 'httptms', 'widelivecomindex', 'wmlidbaeceffffirsttruejul']
# Probability of Spam:  1.0
# Message:  ['oh', 'my', 'god', 'ive', 'found', 'your', 'number', 'again', 'im', 'so', 'glad', 'text', 'me', 'back', 'xafter', 'this', 'msgs', 'cst', 'std', 'ntwk', 'chg', '']
# Probability of Spam:  1.0
# Message:  ['a', 'link', 'to', 'your', 'picture', 'has', 'been', 'sent', 'you', 'can', 'also', 'use', 'httpaltocoukwavewaveaspo']
# Probability of Spam:  1.0
# Message:  ['double', 'mins', '', '', 'txts', 'on', 'orange', 'tariffs', 'latest', 'motorola', 'sonyericsson', '', 'nokia', 'with', 'bluetooth', 'free', 'call', 'mobileupd', 'on', '', 'or', 'calloptouthf']
# Probability of Spam:  1.0
# Message:  ['urgent', 'this', 'is', 'our', 'nd', 'attempt', 'to', 'contact', 'u', 'your', '', 'prize', 'from', 'yesterday', 'is', 'still', 'awaiting', 'collection', 'to', 'claim', 'call', 'now', '', 'aclpm']
# Probability of Spam:  1.0
# Message:  ['dear', 'dave', 'this', 'is', 'your', 'final', 'notice', 'to', 'collect', 'your', '', 'tenerife', 'holiday', 'or', '', 'cash', 'award', 'call', '', 'from', 'landline', 'tcs', 'sae', 'box', 'cwwx', 'ppm']
# Probability of Spam:  1.0
# Message:  ['tells', 'u', '', 'call', '', 'to', 'claim', '', 'prize', 'u', 'have', '', 'enter', 'all', 'ur', 'mobile', '', 'personal', 'details', '', 'the', 'prompts', 'careful']
# Probability of Spam:  1.0
# Message:  ['your', '', 'account', 'for', 'xxxxxxxxx', 'shows', '', 'unredeemed', 'points', 'to', 'claim', 'call', '', 'identifier', 'code', 'xxxxx', 'expires', '']
# Probability of Spam:  1.0
# Message:  ['do', 'you', 'want', 'a', 'new', 'video', 'handset', '', 'anytime', 'any', 'network', 'mins', 'half', 'price', 'line', 'rental', 'camcorder', 'reply', 'or', 'call', '', 'for', 'delivery', 'tomorrow']
# Probability of Spam:  1.0
# Message:  ['you', 'have', 'an', 'important', 'customer', 'service', 'announcement', 'call', 'freephone', '', '', '', 'now']
# Probability of Spam:  1.0
# Average Probability of Spam:  0.9978522586016244

# %% [markdown]
# Validate The Model We Created On The Test Data

# %%
cutoff = avg

correct = 0

# Test Good Messages
for i in messages[0][x_train_good:]:
    formatted_msg = parse_message_into_vectors(i)
    
    # print("Message: ", formatted_msg)
    prob = computeProbabilityOfSpam(formatted_msg, x_train_spam_word_counts, x_train_good_word_counts)
    
    if prob < cutoff:
        correct += 1

# Test Spam Messages  
for i in messages[1][x_train_spam:]:
    formatted_msg = parse_message_into_vectors(i)
    
    # print("Message: ", formatted_msg)
    prob = computeProbabilityOfSpam(formatted_msg, x_train_spam_word_counts, x_train_good_word_counts)
    
    if prob >= cutoff:
        correct += 1
        
print("Correct: ", correct)
print("Accuracy: ", correct/(x_test_good + x_test_spam))
# Out:
# Correct:  1598
# Accuracy:  0.9551703526598924
